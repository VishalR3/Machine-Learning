# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s=np.array([0.07,0.11,0.15,0.19,0.23,0.27,0.31])

# %%
E=np.array([[0.388,0.392,0.394,0.390,0.351,0.366,0.368],[0.384,0.393,0.394,0.402,0.308,0.328,0.336],[0.391,0.393,0.392,0.392,0.376,0.377,0.380],[0.380,0.388,0.377,0.361,0.264,0.307,0.310],[0.332,0.346,0.340,0.330,0.220,0.268,0.275],[0.347,0.350,0.333,0.297,0.236,0.274,0.282]])

# %%
E
# Out:
# array([[0.388, 0.392, 0.394, 0.39 , 0.351, 0.366, 0.368],
#        [0.384, 0.393, 0.394, 0.402, 0.308, 0.328, 0.336],
#        [0.391, 0.393, 0.392, 0.392, 0.376, 0.377, 0.38 ],
#        [0.38 , 0.388, 0.377, 0.361, 0.264, 0.307, 0.31 ],
#        [0.332, 0.346, 0.34 , 0.33 , 0.22 , 0.268, 0.275],
#        [0.347, 0.35 , 0.333, 0.297, 0.236, 0.274, 0.282]])

# %%
plt.figure(figsize=(20,8))
plt.title("")
plt.xlabel("Difference from Reference point (s)",fontsize=14)
plt.ylabel("Total Head (E)",fontsize=14)
plt.plot(s,E[0],'ro-',s,E[1],'ro-',s,E[2],'ro-',s,E[3],'ro-',s,E[4],'ro-',s,E2[0],'ro-',s,E2[1],'ro-',s,E2[2],'ro-')
plt.show()

# %%
E2=np.array([[0.341,0.344,0.336,0.320,0.265,0.288,0.29],[0.360,0.365,0.357,0.341,0.284,0.308,0.315],[0.357,0.366,0.366,0.370,0.270,0.296,0.303]])

# %%
E2
# Out:
# array([[0.341, 0.344, 0.336, 0.32 , 0.265, 0.288, 0.29 ],
#        [0.36 , 0.365, 0.357, 0.341, 0.284, 0.308, 0.315],
#        [0.357, 0.366, 0.366, 0.37 , 0.27 , 0.296, 0.303]])
