# %%
import pandas as pd
advert=pd.read_csv("tvmarketing.csv")

# %%
advert.head()
advert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
# TV       200 non-null float64
# Sales    200 non-null float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
advert.describe()
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
import seaborn as sns

# %%
sns.pairplot(advert, x_vars=["TV"],y_vars=["Sales"],size=7,aspect=0.7,kind="scatter")
# Out:
# D:\Anaconda\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
x=advert.TV
y=advert.Sales

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, Y_train, Y_test= train_test_split(x,y,train_size=0.8,random_state=100)

# %%
print(np.shape(X_train))
print(type(Y_train))
print(type(X_test))
print(type(X_test))
# Out:
# (160,)
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, **options)>

# %%
import numpy as np

X_train=X_train[: , np.newaxis]
X_test=X_test[:,np.newaxis]

# %%
Y_train.shape
# Out:
# (160,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit( X_train , Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [0.04610976]
# 7.113008222196275

# %% [markdown]
# y=6.98966 + 0.04649736

# %%
c=lr.intercept_
m=lr.coef_

# %%
y_pred=c + m*x

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,20))
plt.plot(x,y_pred,'r-',x,y,'bo')
plt.xlabel("TV")
plt.ylabel("Sales")
plt.show()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([ 7.47266432, 18.09635222, 13.3470473 , 17.15110221, 18.25773636,
#        16.64850586, 13.53148632, 16.2242961 , 17.09115952, 17.10960343,
#        12.51707168, 17.69519733,  9.70437654, 15.77242049, 11.13377899,
#        11.45654728, 14.01563877, 14.96088877, 14.65195341, 12.31879973,
#        17.01277294, 13.07961071, 16.12285464, 15.27443512, 15.6387022 ,
#        17.27098757, 17.2479327 , 10.58507289, 15.6387022 , 12.78911924,
#        10.26691557, 10.29458142, 12.69228876, 15.80008634,  9.41849605,
#        12.66923388, 11.59487655, 14.87789121, 17.36781806, 16.02141317])

# %%
c =np.arange(1,61,1)

# %%
plt.figure(figsize=(10,5))
plt.plot(c,Y_test,'r-')
plt.plot(c,y_pred,'b-')
plt.show()

# %%
d=np.arange(1,41,1)
plt.figure(figsize=(6.66,5))
plt.plot(d,Y_test,'r-')
plt.plot(d,y_pred,'b-')
plt.show()

# %%
d=np.arange(1,41,1)
plt.figure(figsize=(6.66,5))
plt.plot(d,Y_test-y_pred,'g-')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse= mean_squared_error(Y_test,y_pred)

# %%
r_squared=r2_score(Y_test,y_pred)

# %%
print(mse)
print(r_squared)
# Out:
# 9.687069547890871
# 0.5441581483697225

# %%
tt=pd.read_excel("Timetable.xlsx")

# %%
tt["8:00 - 9:00"].map({ "NaN" : "No Class" })
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: 8:00 - 9:00, dtype: object

# %%
tt
# Out:
#          Day           8:00 - 9:00 9:00-10:00            10:00-11:00  \
# 0     Monday    Fluid Dynamics Lab        NaN                    NaN
# 1    Tuesday                   NaN        NaN                    NaN
# 2  Wednesday                   NaN        NaN  Mass Tranfer Tutorial
# 3   Thursday          Language Lab        NaN                    NaN
# 4     Friday  Basic Electrical Lab        NaN                    NaN
#
#    11:00-12:00      1:15-2:15     2:15- 3:15   3: 15 - 4:15        4:15 - 5:15
# 0          NaN  Heat Transfer  Mass Transfer            CRE  Cognitive science
# 1          NaN  Mass Transfer            CRE      Fuels N C  Cognitive science
# 2          NaN            NaN            NaN            NaN                NaN
# 3          NaN            CRE      Fuels N C  Heat Transfer  Cognitive science
# 4          NaN      Fuels N C  Heat Transfer  Mass Transfer                NaN
