# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(5,100,100)
y=np.linspace(10,1000,100)

# %%
plt.plot(x,y)

# %%
a=np.linspace(1,100,10)
b=np.linspace(1,10,10)

# %%
plt.plot(a,b,"b+")
plt.ylabel("Voltage")
plt.title("Ohm's Law")
plt.xlim(1,100)
plt.ylim(1,10)
plt.show()

# %%
x=np.arange(1,10,0.1)
y=np.sin(x)
z=np.cos(x)
w=np.zeros((90,1))

plt.plot(x,y,"ro",x,z,"g^",x,w,"b--")

# %%
from matplotlib.ticker import NullFormatter

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("y=sin(x)")
plt.plot(x,y)

plt.subplot(2,2,2)
plt.title("y=cos(x)")
z=np.cos(x)
plt.plot(x,z)

plt.subplot(2,2,3)
plt.title("y=tan(x)")
w=np.tan(x)
plt.plot(x,w)

plt.subplot(2,2,4)
plt.title("y=log(x)")
y=np.log(x)
plt.plot(x,y)

plt.show()

# %%
x=np.arange(1,10,0.1)
plt.hist(x,x**3)
plt.ylim(0,12)
plt.xlim(0,12)
plt.show()

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")
df=pd.read_csv("D:/DC+/Udemy - Machine Learning A-Z  Become Kaggle Master !!-VENDETTA-!!/7. Data Visualisation/market_fact.csv")
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
plt.figure(2)
plt.subplot(1,2,1)
sns.distplot(df['Shipping_Cost'],hist=False)
plt.show()

plt.subplot(1,2,2)
sns.distplot(df['Profit'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.Shipping_Cost.describe()
# Out:
# count    8399.000000
# mean       12.838557
# std        17.264052
# min         0.490000
# 25%         3.300000
# 50%         6.070000
# 75%        13.990000
# max       164.730000
# Name: Shipping_Cost, dtype: float64

# %%
y=np.array([0.0256,0.1536,0.3456,0.3456,0.1296])
x=np.linspace(0,4,5)
plt.hist(y,animated=True)
plt.xlabel("X (random Variable)")
plt.ylabel("Probability")
plt.title("Probaility Distribution")
#plt.xlim(0,5)
#plt.ylim(0,1)
plt.show()

# %%
val = list(zip(x,y))
data=pd.DataFrame(data=val,columns=['x','y'])
data.set_index("x",inplace=True)
plt.hist(data)
plt.show()

# %%
z=pd.DataFrame({"Y":y})

# %%
z.describe()
# Out:
#               Y
# count  5.000000
# mean   0.200000
# std    0.141353
# min    0.025600
# 25%    0.129600
# 50%    0.153600
# 75%    0.345600
# max    0.345600

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import scipy as sp

# %%
sp
# Out:
# <module 'scipy' from 'D:\\Anaconda\\lib\\site-packages\\scipy\\__init__.py'>

# %%
 import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('IMG_20190916_194818_777.jpg',0)
edges = cv2.Canny(img,400,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
#X, Y, Z = axes3d.get_test_data(0.05)
X=np.arange(0,10,0.1)
X=X[:,np.newaxis]
Y=np.arange(0,10,0.1)
Y=Y[:,np.newaxis]
Z=20-np.sqrt(X**2+Y**2)

# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()
X.shape
# Out:
# (100, 1)
